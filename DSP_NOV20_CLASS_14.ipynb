# %%
.reset_index()

.dropna( how = 'any' )

.groupby()
.pivot()

.pivot_table()

# %%
import numpy as np
import pandas as pd

# %%
stores = pd.read_csv('D:/SampleData/stores.csv')

# %%
stores.reset_index()
# Out:
#     index StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0       0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1       1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2       2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3       3    STR104      Super Market  Super Market    Delhi           21.4
# 4       4    STR105     Central Store  Super Market    Delhi           18.7
# 5       5    STR106      Apparel Zone       Apparel    Delhi           18.1
# 6       6    STR107     Fashion Bazar       Apparel    Delhi           14.3
# 7       7    STR108     Digital Bazar  Electronincs    Delhi           24.4
# 8       8    STR109  Electronics Zone  Electronincs  Chennai           22.8
# 9       9    STR110      Apparel Zone       Apparel  Chennai           19.2
# 10     10    STR111       Super Bazar  Super Market  Chennai           17.8
# ...

# %%
stores.groupby(['Location', 'StoreType']).TotalSales.sum().reset_index().pivot(index = 'Location', 
                    columns = 'StoreType', values = 'TotalSales')
# Out:
# StoreType  Apparel  Electronincs  Super Market
# Location
# Chennai      915.4         600.8         719.2
# Delhi        745.0         306.7         726.0
# Kolkata      525.0         521.0         566.4
# Mumbai       700.7         790.0         266.9

# %%
stores.pivot_table( index = 'Location', columns = 'StoreType', values = 'TotalSales', 
                   aggfunc = 'sum' )
# Out:
# StoreType  Apparel  Electronincs  Super Market
# Location
# Chennai      915.4         600.8         719.2
# Delhi        745.0         306.7         726.0
# Kolkata      525.0         521.0         566.4
# Mumbai       700.7         790.0         266.9

# %% [markdown]
# #### What is the purpose of getting %age of missings in every variable?

# %% [raw]
# wether we need to eliminate that data or should we imputate it

# %% [markdown]
# ### Today's topics

# %% [raw]
# Groups and Bins:
#     pd.cut( x, bins )
#         bins = binsize
#         bins = range(start, end, step)
#         bins = [ start, ...., end (in asc order ]
#
#     pd.qcut( x, q )
#         q = 4 : quartile analysis
#         q = 10 : decile analysis
#
# Combining the data
#     Joins
#         pd.merge( left = , right = , left_on = , right_on = , how = )
#
#     Append
#         .append( [], ignore_index = )
#         pd.concat( [], axis = 0 )
#
#     Horizontal concat
#         pd.concat( [], axis = 1 )

# %% [raw]
# 11 - 90 years
#
# Groups of the data
# -------------------------
# <= 19: Teens
# 20 - 25: Young
# 26 - 45: Adults
# 46 - 60: Matured
# > 60 : Old
#
#
# Bins
# -------------------------
# 11 - 20
# 21 - 30
# 31 - 40
# ...
#
# 81 - 90
#
# pd.cut()
# pd.qcut()

# %% [markdown]
# ### Groups and Bins

# %%
print( stores.TotalSales.min(), stores.TotalSales.max() )
# Out:
# 71.1 472.0

# %%
pd.cut( stores.TotalSales, 3 )

# %%
stores['Bins'] = pd.cut( stores.TotalSales, 3 )

# %%
stores[['TotalSales', 'Bins']].head(2)
# Out:
#    TotalSales               Bins
# 0       160.0  (70.699, 204.733]
# 1       160.0  (70.699, 204.733]

# %%
pd.cut( stores.TotalSales, range(0, 501, 100) ).head(2)
# Out:
# 0    (100, 200]
# 1    (100, 200]
# Name: TotalSales, dtype: category
# Categories (5, interval[int64]): [(0, 100] < (100, 200] < (200, 300] < (300, 400] < (400, 500]]

# %%
pd.cut( stores.TotalSales, [0, 100, 150, 180, 250, 370, 450, 500] ).head(2)
# Out:
# 0    (150, 180]
# 1    (150, 180]
# Name: TotalSales, dtype: category
# Categories (7, interval[int64]): [(0, 100] < (100, 150] < (150, 180] < (180, 250] < (250, 370] < (370, 450] < (450, 500]]

# %%
pd.qcut( stores.TotalSales, 10 ).head(2)
# Out:
# 0    (142.06, 160.0]
# 1    (142.06, 160.0]
# Name: TotalSales, dtype: category
# Categories (10, interval[float64]): [(71.09899999999999, 80.61] < (80.61, 120.14] < (120.14, 142.06] < (142.06, 160.0] ... (275.8, 303.1] < (303.1, 350.8] < (350.8, 396.0] < (396.0, 472.0]]

# %%
stores.TotalSales.median()
# Out:
# 196.3

# %% [markdown]
# ### Types of data

# %% [raw]
# Every tool can understand the data from data types:
#
# Char
#     str
#
# Numeric
#     int
#     float
#     bool
#     date and time
#
# in data science, we want to categorize the variables as Categorical and Continuous
#
# Categorical
#     Ordinal
#     Nominal
#
# Continuous
#
# Groups and Bins: convert the continuous data into ordinal categorical data

# %% [raw]
# Customer Data:
#
# Categorical:
# Name: N1, N2, ...
# CustID: 1001, 1002, ....
# DOB: 1 jan 2000, 12 Nov 1989, 30 Jan 1999....
# Address: N, S, E, W
# Phone: 1000000000, 9876543210, ....
# gender: 0, 1
# Profession: GServent, Self Emp, Private, Stu
#
# Continuous:
# Salary:
# Age:
# Sales:
#
# Text | char data is always categorical
# Problem is with the numbers

# %% [markdown]
# ### Joins / Merge

# %%
demog = pd.read_csv('D:/SampleData/Demographic_Data.csv')
demog
# Out:
#   CustName Gender  Age   Location  Salary Education      Mobile
# 0     Alex      M   21         UK   19159       PhD  8834777722
# 1      Tom      M   34        USA   10461         X  8812237772
# 2   Michel      M   25      India   19961       XII  8834777232
# 3  Michael      M   28    Belgium     821     B.Com  8831234222
# 4   Patrik      M   29  Australia   13743       MBA  8823427722
# 5     Hans      M   34      Japan   25000        MS  8834772342
# 6  Biliana      F   26     Russia    3000        MS  8837427722
# 7      Raj      M   29      India    2000        MS  9892877722
# 8    Laila      F   26      India    4000       MBA  7867277722
# 9  Prabhas      F   35      India   20000       MBA  8834772321

# %%
trans = pd.read_csv('D:/SampleData/Transaction_Summary.csv')
trans
# Out:
#   CustomerName  Total_Transaction_value  No_of_holding_prods  No_of_visits  \
# 0         Alex                    19159                    3             3
# 1          Tom                    10461                    2             7
# 2       Michel                    19961                    4             8
# 3         Hans                      821                    1             2
# 4      Biliana                    13743                    6             9
# 5       Rajesh                    25000                    2            12
# 6        Laila                     3000                    1             6
# 7      Prabhas                     2000                    2             4
# 8         Ramu                    30000                    6             2
#
#    No_of_channels
# 0               1
# 1               2
# 2               3
# 3               2
# 4               3
# 5               2
# 6               1
# 7               2
# 8               3

# %%
# inner join
pd.merge( left=demog, right=trans, how='inner', left_on='CustName', right_on='CustomerName' )
# Out:
#   CustName Gender  Age Location  Salary Education      Mobile CustomerName  \
# 0     Alex      M   21       UK   19159       PhD  8834777722         Alex
# 1      Tom      M   34      USA   10461         X  8812237772          Tom
# 2   Michel      M   25    India   19961       XII  8834777232       Michel
# 3     Hans      M   34    Japan   25000        MS  8834772342         Hans
# 4  Biliana      F   26   Russia    3000        MS  8837427722      Biliana
# 5    Laila      F   26    India    4000       MBA  7867277722        Laila
# 6  Prabhas      F   35    India   20000       MBA  8834772321      Prabhas
#
#    Total_Transaction_value  No_of_holding_prods  No_of_visits  No_of_channels
# 0                    19159                    3             3               1
# 1                    10461                    2             7               2
# 2                    19961                    4             8               3
# ...

# %%
# left join
pd.merge( left=demog, right=trans, how='left', left_on='CustName', right_on='CustomerName' )
# Out:
#   CustName Gender  Age   Location  Salary Education      Mobile CustomerName  \
# 0     Alex      M   21         UK   19159       PhD  8834777722         Alex
# 1      Tom      M   34        USA   10461         X  8812237772          Tom
# 2   Michel      M   25      India   19961       XII  8834777232       Michel
# 3  Michael      M   28    Belgium     821     B.Com  8831234222          NaN
# 4   Patrik      M   29  Australia   13743       MBA  8823427722          NaN
# 5     Hans      M   34      Japan   25000        MS  8834772342         Hans
# 6  Biliana      F   26     Russia    3000        MS  8837427722      Biliana
# 7      Raj      M   29      India    2000        MS  9892877722          NaN
# 8    Laila      F   26      India    4000       MBA  7867277722        Laila
# 9  Prabhas      F   35      India   20000       MBA  8834772321      Prabhas
#
#    Total_Transaction_value  No_of_holding_prods  No_of_visits  No_of_channels
# ...

# %%
# right join
pd.merge( left=demog, right=trans, how='right', left_on='CustName', right_on='CustomerName' )
# Out:
#   CustName Gender   Age Location   Salary Education        Mobile  \
# 0     Alex      M  21.0       UK  19159.0       PhD  8.834778e+09
# 1      Tom      M  34.0      USA  10461.0         X  8.812238e+09
# 2   Michel      M  25.0    India  19961.0       XII  8.834777e+09
# 3     Hans      M  34.0    Japan  25000.0        MS  8.834772e+09
# 4  Biliana      F  26.0   Russia   3000.0        MS  8.837428e+09
# 5    Laila      F  26.0    India   4000.0       MBA  7.867278e+09
# 6  Prabhas      F  35.0    India  20000.0       MBA  8.834772e+09
# 7      NaN    NaN   NaN      NaN      NaN       NaN           NaN
# 8      NaN    NaN   NaN      NaN      NaN       NaN           NaN
#
#   CustomerName  Total_Transaction_value  No_of_holding_prods  No_of_visits  \
# 0         Alex                    19159                    3             3
# 1          Tom                    10461                    2             7
# 2       Michel                    19961                    4             8
# ...

# %%
# outer join
pd.merge( left=demog, right=trans, how='outer', left_on='CustName', right_on='CustomerName' )
# Out:
#    CustName Gender   Age   Location   Salary Education        Mobile  \
# 0      Alex      M  21.0         UK  19159.0       PhD  8.834778e+09
# 1       Tom      M  34.0        USA  10461.0         X  8.812238e+09
# 2    Michel      M  25.0      India  19961.0       XII  8.834777e+09
# 3   Michael      M  28.0    Belgium    821.0     B.Com  8.831234e+09
# 4    Patrik      M  29.0  Australia  13743.0       MBA  8.823428e+09
# 5      Hans      M  34.0      Japan  25000.0        MS  8.834772e+09
# 6   Biliana      F  26.0     Russia   3000.0        MS  8.837428e+09
# 7       Raj      M  29.0      India   2000.0        MS  9.892878e+09
# 8     Laila      F  26.0      India   4000.0       MBA  7.867278e+09
# 9   Prabhas      F  35.0      India  20000.0       MBA  8.834772e+09
# 10      NaN    NaN   NaN        NaN      NaN       NaN           NaN
# 11      NaN    NaN   NaN        NaN      NaN       NaN           NaN
#
# ...

# %% [markdown]
# ### append

# %%
q1 = pd.read_csv('D:/SampleData/POS_Q1.csv')
q2 = pd.read_csv('D:/SampleData/POS_Q2.csv')
q3 = pd.read_csv('D:/SampleData/POS_Q3.csv')
q4 = pd.read_csv('D:/SampleData/POS_Q4.csv')

# %%
q1.append([q2, q3, q4]).head(2)
# Out:
#             Date  Configuration Customer Postcode Store Postcode  \
# 0  01-01-13 0:01            163          EC4V 5BH        SE1 2BN
# 1  01-01-13 0:02            320           SW4 0JL       SW12 9HD
#
#    Retail Price  month
# 0           455      1
# 1           545      1

# %%
pd.concat( [q1, q2, q3, q4], axis = 0 ).head(2)
# Out:
#             Date  Configuration Customer Postcode Store Postcode  \
# 0  01-01-13 0:01            163          EC4V 5BH        SE1 2BN
# 1  01-01-13 0:02            320           SW4 0JL       SW12 9HD
#
#    Retail Price  month
# 0           455      1
# 1           545      1

# %%
pd.concat( [ stores, pd.cut( stores.TotalSales, range(0, 500, 100)) ], axis = 1 ).head(2)
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
#
#    Staff_Cnt TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60      160.0              110             3.9       2.620
# 1         60      160.0              110             3.9       2.875
#
#    ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment  \
# 0          16.46         0               1       4             4
# 1          17.02         0               1       4             4
#
#                 Bins  TotalSales
# 0  (70.699, 204.733]  (100, 200]
# 1  (70.699, 204.733]  (100, 200]
