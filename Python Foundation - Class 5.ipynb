# %% [markdown]
# # Python Foundation: Class 5 topics
# > <p>
#     1. Import the data from files as DataFrame <br/>
#     2. Basic data analysis <br/>
#     3. Data Manipulation / Data Cleaning <br/>
#         - Structural <br/>
#         - Content based <br/>
#     4. Exploratory Analysis
#  </p>

# %% [markdown]
# Objective of the analysis
#
# Availabilty of the data
#     - CREATE RANDOM DATA
#     - DATA IMPORT
#
# Structural understanding
#
# Data understanding
#
# Data Prep:
#     Structural
#         1. Add new columns
#         2. Delete some columns
#         3. Rearrange the columns
#         4. Subsetting (Extracting some columns)
#         5. Rename the columns
#         6. Change the datatypes
#
#     Content based
#         1. Filters
#         2. Sort
#         3. Removal of duplicates
#         4. Data imputation
#             1. Missing value treatment
#             2. Outlier treatment
#         5. Binning or Grouping of the data
#         6. Encoding
#         7. Grouping of the data/ Summaries
#         8. Joins/Merge
#         9. Appending
#
# Exploratory analysis

# %%
import pandas as pd

# %%
a = pd.read_excel('D:/SampleData/AutoInsurance.xlsx', sheet_name='AutoBi')

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
# import the data
stores = pd.read_csv('D:/SampleData/stores.csv', sep = ',')

# %%
type(stores)
# Out:
# pandas.core.frame.DataFrame

# %%
stores.ndim
# Out:
# 2

# %%
stores.shape
# Out:
# (32, 15)

# %%
stores.size
# Out:
# 480

# %%
stores.dtypes
# Out:
# pandas.core.series.Series

# %%
stores.memory_usage()
# Out:
# Index               80
# StoreCode          256
# StoreName          256
# StoreType          256
# Location           256
# OperatingCost      256
# Staff_Cnt          256
# TotalSales         256
# Total_Customers    256
# AcqCostPercust     256
# BasketSize         256
# ProfitPercust      256
# OwnStore           256
# OnlinePresence     256
# Tenure             256
# StoreSegment       256
# dtype: int64

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 15 columns):
# StoreCode          32 non-null object
# StoreName          32 non-null object
# StoreType          32 non-null object
# Location           32 non-null object
# OperatingCost      32 non-null float64
# Staff_Cnt          32 non-null int64
# TotalSales         32 non-null float64
# Total_Customers    32 non-null int64
# AcqCostPercust     29 non-null float64
# BasketSize         32 non-null float64
# ProfitPercust      32 non-null float64
# OwnStore           32 non-null int64
# OnlinePresence     32 non-null int64
# Tenure             32 non-null int64
# StoreSegment       32 non-null int64
# dtypes: float64(5), int64(6), object(4)
# memory usage: 3.8+ KB

# %%
stores.tail(2)
# Out:
#    StoreCode      StoreName     StoreType Location  OperatingCost  Staff_Cnt  \
# 30    STR131  Fashion Bazar       Apparel  Kolkata           15.0         80
# 31    STR132  Digital Bazar  Electronincs  Kolkata           21.4         40
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 30       301.0              335            3.54        3.57           14.6
# 31       121.0              109            4.11        2.78           18.6
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment
# 30         0               1       5             4
# 31         1               1       4             2

# %%
stores.describe()
# Out:
#        OperatingCost  Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  \
# count      32.000000  32.000000   32.000000        32.000000       29.000000
# mean       20.090625  61.875000  230.721875       146.687500        3.651034
# std         6.026948  17.859216  123.938694        68.562868        0.532664
# min        10.400000  40.000000   71.100000        52.000000        2.760000
# 25%        15.425000  40.000000  120.825000        96.500000        3.150000
# 50%        19.200000  60.000000  196.300000       123.000000        3.730000
# 75%        22.800000  80.000000  326.000000       180.000000        3.920000
# max        33.900000  80.000000  472.000000       335.000000        4.930000
#
#        BasketSize  ProfitPercust   OwnStore  OnlinePresence     Tenure  \
# count   32.000000      32.000000  32.000000       32.000000  32.000000
# mean     3.217250      17.848750   0.437500        0.406250   3.687500
# ...

# %% [markdown]
# ## Subsetting

# %%
[]
loc and iloc
df.columnname

# %%
stores['StoreCode'].head()
# Out:
# 0    STR101
# 1    STR102
# 2    STR103
# 3    STR104
# 4    STR105
# Name: StoreCode, dtype: object

# %%
stores[['StoreCode', 'StoreName']].head()
# Out:
#   StoreCode         StoreName
# 0    STR101  Electronics Zone
# 1    STR102      Apparel Zone
# 2    STR103       Super Bazar
# 3    STR104      Super Market
# 4    STR105     Central Store

# %%
stores.iloc[:,0:4].head(4)
# Out:
#   StoreCode         StoreName     StoreType Location
# 0    STR101  Electronics Zone  Electronincs    Delhi
# 1    STR102      Apparel Zone       Apparel    Delhi
# 2    STR103       Super Bazar  Super Market    Delhi
# 3    STR104      Super Market  Super Market    Delhi

# %%
stores.loc[:, ['StoreCode', 'StoreName']].head(4)
# Out:
#   StoreCode         StoreName
# 0    STR101  Electronics Zone
# 1    STR102      Apparel Zone
# 2    STR103       Super Bazar
# 3    STR104      Super Market

# %%
stores.StoreCode
# Out:
# 0     STR101
# 1     STR102
# 2     STR103
# 3     STR104
# 4     STR105
# 5     STR106
# 6     STR107
# 7     STR108
# 8     STR109
# 9     STR110
# 10    STR111
# 11    STR112
# 12    STR113
# 13    STR114
# 14    STR115
# 15    STR116
# 16    STR117
# 17    STR118
# 18    STR119
# 19    STR120
# 20    STR121
# 21    STR122
# 22    STR123
# 23    STR124
# 24    STR125
# 25    STR126
# 26    STR127
# 27    STR128
# 28    STR129
# 29    STR130
# 30    STR131
# 31    STR132
# Name: StoreCode, dtype: object

# %%
stores.head(2)
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110             3.9       2.620
# 1         60       160.0              110             3.9       2.875
#
#    ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46         0               1       4             4
# 1          17.02         0               1       4             4

# %% [markdown]
# ## Reorder the columns

# %%
stores[['StoreType', 'StoreName', 'Location']].head(2)
# Out:
#       StoreType         StoreName Location
# 0  Electronincs  Electronics Zone    Delhi
# 1       Apparel      Apparel Zone    Delhi

# %%
stores.iloc[:,[3, 6, 2, 1]].head(2)
# Out:
#   Location  TotalSales     StoreType         StoreName
# 0    Delhi       160.0  Electronincs  Electronics Zone
# 1    Delhi       160.0       Apparel      Apparel Zone

# %% [markdown]
# ## Adding new conditional columns

# %%
stores.OperatingCost.head()
# Out:
# 0    21.0
# 1    21.0
# 2    22.8
# 3    21.4
# 4    18.7
# Name: OperatingCost, dtype: float64

# %%
stores.TotalSales.head()
# Out:
# 0    160.0
# 1    160.0
# 2    108.0
# 3    258.0
# 4    360.0
# Name: TotalSales, dtype: float64

# %%
(stores.TotalSales - stores.OperatingCost).head()
# Out:
# 0    139.0
# 1    139.0
# 2     85.2
# 3    236.6
# 4    341.3
# dtype: float64

# %%
stores.shape
# Out:
# (32, 15)

# %%
stores['NetProfit'] = stores.TotalSales - stores.OperatingCost # correct

# %%
stores = stores.TotalSales - stores.OperatingCost # incorrect, never recomended

# %%
stores.NetProfit1 = stores.TotalSales - stores.OperatingCost # incorrect, syntax error
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
stores.head()
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110            3.90       2.620
# 1         60       160.0              110            3.90       2.875
# 2         40       108.0               93            3.85       2.320
# 3         60       258.0              110            3.08       3.215
# 4         80       360.0              175            3.15       3.440
#
#    ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46         0               1       4             4
# ...

# %%
stores = stores.assign(NetProfit1 = stores.TotalSales - stores.OperatingCost, NetProfit2 = stores.TotalSales - (stores.OperatingCost + stores.AcqCostPercust))

# %%
stores = stores.assign(np1 = stores.TotalSales - stores.OperatingCost, np2 = stores.TotalSales - stores.OperatingCost)

# %%
stores.head(2)
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110             3.9       2.620
# 1         60       160.0              110             3.9       2.875
#
#    ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment    np1  \
# 0          16.46         0               1       4             4  139.0
# 1          17.02         0               1       4             4  139.0
#
#      np2  NetProfit1  NetProfit2
# 0  139.0       139.0       135.1
# 1  139.0       139.0       135.1

# %%
['NewColumn']
.assign(kwarg1 = value1, ........)

# %% [markdown]
# ## Delete the columns

# %%
stores.drop?

# %%
stores.drop(columns = 'np1', axis = 'columns').head(4)
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110            3.90       2.620
# 1         60       160.0              110            3.90       2.875
# 2         40       108.0               93            3.85       2.320
# 3         60       258.0              110            3.08       3.215
#
#    ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment    np2  \
# 0          16.46         0               1       4             4  139.0
# 1          17.02         0               1       4             4  139.0
# ...

# %% [markdown]
# ## rename the columns

# %%
stores.rename(columns = {'TotalSales': 'NetTotalSales', 'OperatingCost': 'NetOperatingCost'}).head(4)
# Out:
#   StoreCode         StoreName     StoreType Location  NetOperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi              21.0
# 1    STR102      Apparel Zone       Apparel    Delhi              21.0
# 2    STR103       Super Bazar  Super Market    Delhi              22.8
# 3    STR104      Super Market  Super Market    Delhi              21.4
#
#    Staff_Cnt  NetTotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60          160.0              110            3.90       2.620
# 1         60          160.0              110            3.90       2.875
# 2         40          108.0               93            3.85       2.320
# 3         60          258.0              110            3.08       3.215
#
#    ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment    np1  \
# 0          16.46         0               1       4             4  139.0
# 1          17.02         0               1       4             4  139.0
# ...

# %% [markdown]
# ## Data Import

# %%
# import the pandas package
import pandas as pd

# %%
# Import the data from files as DataFrame
stores = pd.read_csv('D:/SampleData/Stores.csv')

# %%
score = pd.read_csv('D:/SampleData/score.csv')

# %% [markdown]
# ## Basic data analysis
# > 1. Check type of data structure
# > 2. No of dimensions
# > 3. Size of the data
# > 4. Shape of the data
# > 5. Columns
# > 6. Count of columns
# > 7. Data types of each column
# > 8. No of non missing values/records in each column
# > 9. Freq table of data types
# > 10. Memory used
# > 11. See sample records
# > 12. Complete structural summary
# > 13. Data descriptives

# %% [markdown]
# ## Data Manipulation / Data Cleaning - Structural
# > 1. Subsetting (Extracting Column/s)
# > 2. Rearrange/Reorder the column/s
# > 3. Adding new column/s in dataframe
# > 4. Delete column/s from dataframe
# > 5. Rename the column/s

# %% [markdown]
# ## Data Manipulation / Data Cleaning - Content based
# > 1. Filters
# > 2. Sorting
# > 3. Removal of duplicates
# > 4. Data imputaion
# > 5. Encoding
# > 6. Binning/creating new grouped variables
# > 7. Grouping/Aggregations
# > 8. Joins/Merge
# > 9. Data append
# > 10. Summaries

# %% [markdown]
# ## Filters

# %%
stores
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1     STR102      Apparel Zone       Apparel    Delhi           21.0
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 3     STR104      Super Market  Super Market    Delhi           21.4
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 7     STR108     Digital Bazar  Electronincs    Delhi           24.4
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 12    STR113     Central Store  Super Market  Chennai           17.3
# ...

# %%
# Get records from stores where Location is Delhi
stores[stores.Location == 'Delhi']
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
# 5    STR106      Apparel Zone       Apparel    Delhi           18.1
# 6    STR107     Fashion Bazar       Apparel    Delhi           14.3
# 7    STR108     Digital Bazar  Electronincs    Delhi           24.4
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110            3.90       2.620
# 1         60       160.0              110            3.90       2.875
# 2         40       108.0               93            3.85       2.320
# 3         60       258.0              110            3.08       3.215
# ...

# %%
stores.loc[stores.Location == 'Delhi']
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
# 5    STR106      Apparel Zone       Apparel    Delhi           18.1
# 6    STR107     Fashion Bazar       Apparel    Delhi           14.3
# 7    STR108     Digital Bazar  Electronincs    Delhi           24.4
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110            3.90       2.620
# 1         60       160.0              110            3.90       2.875
# 2         40       108.0               93            3.85       2.320
# 3         60       258.0              110            3.08       3.215
# ...

# %%
# Records from Kolkata where TotalSales > 100
stores.loc[(stores.Location == 'Kolkata') & (stores.TotalSales > 100)]
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 24    STR125  Electronics Zone  Electronincs  Kolkata           19.2
# 26    STR127       Super Bazar  Super Market  Kolkata           26.0
# 28    STR129     Central Store  Super Market  Kolkata           15.8
# 29    STR130      Apparel Zone       Apparel  Kolkata           19.7
# 30    STR131     Fashion Bazar       Apparel  Kolkata           15.0
# 31    STR132     Digital Bazar  Electronincs  Kolkata           21.4
#
#     Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 24         80       400.0              175            3.08       3.845
# 26         40       120.3               91            4.43       2.140
# 28         80       351.0              264            4.22       3.170
# 29         60       145.0              175            3.62       2.770
# 30         80       301.0              335            3.54       3.570
# ...

# %%
# Records from Kolkata where TotalSales > 100 and < 300
stores.loc[(stores.Location == 'Kolkata') & (stores.TotalSales > 100) & (stores.TotalSales < 300)]
# Out:
#    StoreCode      StoreName     StoreType Location  OperatingCost  Staff_Cnt  \
# 26    STR127    Super Bazar  Super Market  Kolkata           26.0         40
# 29    STR130   Apparel Zone       Apparel  Kolkata           19.7         60
# 31    STR132  Digital Bazar  Electronincs  Kolkata           21.4         40
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 26       120.3               91            4.43        2.14           16.7
# 29       145.0              175            3.62        2.77           15.5
# 31       121.0              109            4.11        2.78           18.6
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment    np1    np2  NetProfit1  \
# 26         0               1       5             2   94.3   94.3        94.3
# 29         0               1       5             4  125.3  125.3       125.3
# 31         1               1       4             2   99.6   99.6        99.6
#
#     NetProfit2
# 26       89.87
# ...

# %%
# All store codes and store types from Chennai where OperatingCost > 15
stores.loc[(stores.Location == 'Chennai') & (stores.OperatingCost > 15), ['StoreCode', 'StoreName', 'Location', 'OperatingCost']]
# Out:
#    StoreCode         StoreName Location  OperatingCost
# 8     STR109  Electronics Zone  Chennai           22.8
# 9     STR110      Apparel Zone  Chennai           19.2
# 10    STR111       Super Bazar  Chennai           17.8
# 11    STR112      Super Market  Chennai           16.4
# 12    STR113     Central Store  Chennai           17.3
# 13    STR114      Apparel Zone  Chennai           15.2

# %%
df.loc[row,columns]

# %% [markdown]
# ### Filtering:
# > 1. Get records from stores where Location is Delhi
# > 2. Records from Kolkata where TotalSales > 100 and < 300
# > 3. All store codes and store types from Chennai where OperatingCost > 15

# %%
# sort data acc to one column [Location asc]
stores.sort_values('Location')
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 15    STR116     Digital Bazar  Electronincs  Chennai           10.4
# 14    STR115     Fashion Bazar       Apparel  Chennai           10.4
# 13    STR114      Apparel Zone       Apparel  Chennai           15.2
# 12    STR113     Central Store  Super Market  Chennai           17.3
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 3     STR104      Super Market  Super Market    Delhi           21.4
# ...

# %%
# sort data acc to one column  [TotalSales desc]
stores.sort_values('TotalSales', ascending = False)
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 19    STR120      Super Market  Super Market   Mumbai           33.9
# 18    STR119       Super Bazar  Super Market   Mumbai           30.4
# 17    STR118      Apparel Zone       Apparel   Mumbai           32.4
# 25    STR126      Apparel Zone       Apparel  Kolkata           27.3
# 27    STR128      Super Market  Super Market  Kolkata           30.4
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 20    STR121     Central Store  Super Market   Mumbai           21.5
# 26    STR127       Super Bazar  Super Market  Kolkata           26.0
# 31    STR132     Digital Bazar  Electronincs  Kolkata           21.4
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 29    STR130      Apparel Zone       Apparel  Kolkata           19.7
# 7     STR108     Digital Bazar  Electronincs    Delhi           24.4
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# ...

# %%
# sort data acc to two columns [Location, OperatingCost asc]
stores.sort_values(['Location', 'OperatingCost'])
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 14    STR115     Fashion Bazar       Apparel  Chennai           10.4
# 15    STR116     Digital Bazar  Electronincs  Chennai           10.4
# 13    STR114      Apparel Zone       Apparel  Chennai           15.2
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 12    STR113     Central Store  Super Market  Chennai           17.3
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1     STR102      Apparel Zone       Apparel    Delhi           21.0
# ...

# %%
# sort data acc to two columns [Location, TotalSales desc]
stores.sort_values(['Location', 'TotalSales'], ascending = False)
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 16    STR117  Electronics Zone  Electronincs   Mumbai           14.7
# 23    STR124     Digital Bazar  Electronincs   Mumbai           13.3
# 21    STR122      Apparel Zone       Apparel   Mumbai           15.5
# 22    STR123     Fashion Bazar       Apparel   Mumbai           15.2
# 20    STR121     Central Store  Super Market   Mumbai           21.5
# 17    STR118      Apparel Zone       Apparel   Mumbai           32.4
# 18    STR119       Super Bazar  Super Market   Mumbai           30.4
# 19    STR120      Super Market  Super Market   Mumbai           33.9
# 24    STR125  Electronics Zone  Electronincs  Kolkata           19.2
# 28    STR129     Central Store  Super Market  Kolkata           15.8
# 30    STR131     Fashion Bazar       Apparel  Kolkata           15.0
# 29    STR130      Apparel Zone       Apparel  Kolkata           19.7
# 31    STR132     Digital Bazar  Electronincs  Kolkata           21.4
# ...

# %%
# sort data acc to two columns [Location in asc, TotalSales in desc]
stores.sort_values(['Location', 'TotalSales'], ascending = [True, False])
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 14    STR115     Fashion Bazar       Apparel  Chennai           10.4
# 15    STR116     Digital Bazar  Electronincs  Chennai           10.4
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 12    STR113     Central Store  Super Market  Chennai           17.3
# 13    STR114      Apparel Zone       Apparel  Chennai           15.2
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 3     STR104      Super Market  Super Market    Delhi           21.4
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# ...

# %% [markdown]
# ### Sorting
# > - sort data acc to one column  [Location asc]
# > - sort data acc to one column  [TotalSales desc]
# > - sort data acc to two columns [Location, OperatingCost asc]
# > - sort data acc to two columns [Location, TotalSales desc]
# > - sort data acc to two columns [Location in asc, TotalSales in desc]

# %% [markdown]
# ### Basic data analysis:

# %%
stores.info()

# %%
stores.describe()

# %% [markdown]
# ### Adding new column/s in dataframe:

# %%
stores["TotalProfit"] = stores.TotalSales - stores.OperatingCost

# %%
stores["TotalProfit"] = stores["TotalSales"] - stores["OperatingCost"]

# %%
stores.assign(TotalProfit = stores.TotalSales - stores.OperatingCost)

# %%
stores = stores.assign(TotalProfit = stores.TotalSales - stores.OperatingCost, Discount = stores.TotalSales * 0.1)

# %% [markdown]
# ### Delete column/s from a dataframe:

# %%
stores = stores.drop(["Discount", "Total Profit"], axis = 1)

# %%
stores.drop(['TotalProfit'], axis = 'columns')

# %% [markdown]
# ### Rename column/s:

# %%
stores.rename(columns={"TotalProfit" : "NetProfit", "Discount": "TotalDiscount"})

# %% [markdown]
# ### Filters (applying conditions on the data):

# %%
# Get records from stores where Location is Delhi
stores[stores.Location == "Delhi"]

# %%
stores.loc[stores.Location == "Delhi",:]

# %%
# All store codes and store types from Chennai where OperatingCost > 15

# %%
stores.loc[(stores.Location == "Chennai") & (stores.OperatingCost > 15),["StoreCode", "StoreType"]]

# %% [markdown]
# ### Sorting
#  - sort data acc to one column  [Location asc]
#  - sort data acc to one column  [TotalSales desc]
#  - sort data acc to two columns [Location, OperatingCost asc]
#  - sort data acc to two columns [Location, TotalSales desc]
#  - sort data acc to two columns [Location in asc, TotalSales in desc]

# %%
stores.sort_values("Location")

# %%
stores.sort_values("Location", ascending = True)

# %%
stores.sort_values("TotalSales", ascending = False)

# %%
stores.sort_values(["Location", "OperatingCost"], ascending = True)

# %%
stores.sort_values(["Location", "TotalSales"], ascending = False)

# %%
stores.sort_values(["Location", "TotalSales"], ascending = [True, False])

# %% [markdown]
# ### Remove duplicates:

# %%
score = pd.read_csv("E:/SampleData/Score.csv")

# %%
score.duplicated()

# %%
score[score.duplicated()]

# %%
score.loc[score.duplicated(),:]

# %%
score.loc[-score.Student.duplicated(),:]

# %% [markdown]
# ### Missing Data in Numeric Variables
#
#     Fill missing values with the
#     - Drop rows where data is missing (if you have LOTS of data >1 mn rows)
#     - Mean (if the distribution is symmetric)
#     - Median (if the distribution is skewed)
#     - Zeros (for data that indicates absence of a metric.)
#     - Use predictive modelling techniques to get the app value of the missing
#
# ### Missing Data in Object Variables
# Fill missing values with - the Mode

# %%
import pyodbc
sql_conn = pyodbc.connect('DRIVER={ODBC Driver 13 for SQL Server};SERVER=MANUJKS;DATABASE=db_mar_19;Trusted_Connection=yes') 
query = 'SELECT * FROM TBL_CUSTOMER;'
df = pd.read_sql(query, sql_conn)
df.head()
# Out:
#    CUST_ID_CUS FNAME_CUS  LNAME_CUS     DOB_CUS     PHONE_CUS  \
# 0       100001    Kallie  Blackwood  1975-09-07  415-9170-276
# 1       100002  Johnetta   Abdallah  1995-08-08  919-6014-934
# 2       100003    Bobbye       Rhym  1972-09-18  650-5905-578
# 3       100004   Micaela     Rhymes  1967-08-05  925-1192-329
# 4       100005     Tamar   Hoogland  1994-12-14  740-1061-857
#
#                    EMAIL_CUS
# 0   kallie.blackwood@abc.com
# 1  johnetta_abdallah@abc.com
# 2              brhym@abc.com
# 3     micaela_rhymes@abc.com
# 4              tamar@abc.com

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
